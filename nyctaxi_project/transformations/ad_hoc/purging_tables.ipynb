# %%
date_from = '2025-11-01 00:00:00'

from databricks.connect import DatabricksSession

spark = DatabricksSession.builder.getOrCreate()

# %%
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "nyctaxi.01_bronze.yellow_trips_raw")
dt.delete(f"tpep_pickup_datetime >= TIMESTAMP '{date_from}'")

# %%
df = spark.read.table("nyctaxi.01_bronze.yellow_trips_raw")
print(df.count())

df.show()

# %%
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "nyctaxi.02_silver.yellow_trips_cleansed")
dt.delete(f"tpep_pickup_datetime >= TIMESTAMP '{date_from}'")

# %%
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "nyctaxi.02_silver.yellow_trips_enriched")
dt.delete(f"tpep_pickup_datetime >= TIMESTAMP '{date_from}'")

# %%
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "nyctaxi.03_gold.daily_trip_summary")
dt.delete(f"pickup_date >= TIMESTAMP '{date_from}'")

# %%
df = spark.read.table("nyctaxi.03_gold.daily_trip_summary")
df.show()
