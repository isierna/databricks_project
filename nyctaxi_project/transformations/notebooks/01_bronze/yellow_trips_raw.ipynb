# %%
from pyspark.sql.functions import current_timestamp
from nyctaxi_project.transformations.modules.transformations.metadata import add_processed_timestamp

# %%
from datetime import date
from dateutil.relativedelta import relativedelta

two_months_ago = date.today() - relativedelta(months=4)
formatted_date = two_months_ago.strftime("%Y-%m")


df = spark.read.format("parquet").load(f"/Volumes/nyctaxi/00_landing/data_sources/nyctaxi_yellow/{formatted_date}")

df = add_processed_timestamp(df)

df.write.mode("append").saveAsTable("nyctaxi.01_bronze.yellow_trips_raw")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[2], line 12
#       8 df = spark.read.format("parquet").load(f"/Volumes/nyctaxi/00_landing/data_sources/nyctaxi_yellow/{formatted_date}")
#      10 df = add_processed_timestamp(df)
# ---> 12 df.write.mode("append").saveAsTable("nyctaxi.01_bronze.yellow_trips_raw")
#
# File ~/work/work/databricks_project/.venv/lib/python3.12/site-packages/pyspark/sql/connect/readwriter.py:737, in DataFrameWriter.saveAsTable(self, name, format, mode, partitionBy, **options)
#     735 self._write.table_name = name
#     736 self._write.table_save_method = "save_as_table"
# --> 737 _, _, ei = self._spark.client.execute_command(
#     738     self._write.command(self._spark.client), self._write.observations
#     739 )
#     740 self._callback(ei)
#
# ...

# %%
spark.read.table("nyctaxi.01_bronze.yellow_trips_raw").display()
